# %%
import os
import os.path as osp

import numpy as np
import matplotlib.pyplot as plt

# %%
path = "/home/hcj/code/gns/results/rollouts"
dataset_nm = "SAGMill"
exp_id = 0
data = np.load(osp.join(path, dataset_nm, f"{exp_id}-error-trend.npy"))

# %%
plt.plot(data)
plt.show()
